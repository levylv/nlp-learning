# %%
# from __future__ import absolute_import
# from __future__ import division
# from __future__ import print_function

import argparse
import collections
import hashlib
import math
import os
import random
import sys
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

from tensorflow.contrib.tensorboard.plugins import projector

data_index = 0

# %%
log_dir='/home/luban/lvwei/nlp-learning/word2vec/tf_no_keras.log'

# %%
 # pylint: disable=redefined-outer-name
  def maybe_download(filename, expected_bytes, sha256=None):
    """Download a file if not present, and make sure it's the right size."""
    local_filename = os.path.join(gettempdir(), filename)
    if not os.path.exists(local_filename):
      local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                     local_filename)
    statinfo = os.stat(local_filename)

    if sha256 and _hash_file(local_filename) != sha256:
      raise Exception('Failed to verify ' + local_filename + ' due to hash '
                      'mismatch. Can you get to it with a browser?')

    if statinfo.st_size == expected_bytes:
      print('Found and verified', filename)
    else:
      print(statinfo.st_size)
      raise Exception('Failed to verify ' + local_filename +
                      '. Can you get to it with a browser?')
    return local_filename

# %%
def _hash_file(fpath):
  hasher = hashlib.sha256()
  with open(fpath, 'rb') as fpath_file:
    for chunk in iter(lambda: fpath_file.read(65535), b''):
      hasher.update(chunk)
  return hasher.hexdigest()

  """Example of building, training and visualizing a word2vec model."""
  # Create the directory for TensorBoard variables if there is not.
  if not os.path.exists(log_dir):
    os.makedirs(log_dir)

  # Step 1: Download the data.
  # Note: Source website does not support HTTPS right now.
  url = 'http://mattmahoney.net/dc/'

filename = maybe_download(
  'text8.zip',
  31344016,
  sha256='a6640522afe85d1963ad56c05b0ede0a0c000dddc9671758a6cc09b7a38e5232')
# Out:
# Found and verified text8.zip

# %%
"""Extract the first file enclosed in a zip file as a list of words."""
with zipfile.ZipFile(filename) as f:
  data = tf.compat.as_str(f.read(f.namelist()[0])).split()
vocabulary = data

# %%
data
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english',
#  'revolution',
#  'and',
#  'the',
#  'sans',
#  'culottes',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'whilst',
#  'the',
#  'term',
#  'is',
#  'still',
#  'used',
#  'in',
#  'a',
#  'pejorative',
#  'way',
#  'to',
#  'describe',
#  'any',
#  'act',
#  'that',
#  'used',
#  'violent',
#  'means',
#  'to',
#  'destroy',
#  'the',
#  'organization',
#  'of',
#  'society',
#  'it',
#  'has',
#  'also',
#  'been',
#  'taken',
#  'up',
#  'as',
#  'a',
#  'positive',
#  'label',
#  'by',
#  'self',
#  'defined',
#  'anarchists',
#  'the',
#  'word',
#  'anarchism',
#  'is',
#  'derived',
#  'from',
#  'the',
#  'greek',
#  'without',
#  'archons',
#  'ruler',
#  'chief',
#  'king',
#  'anarchism',
#  'as',
#  'a',
#  'political',
#  'philosophy',
#  'is',
#  'the',
#  'belief',
#  'that',
#  'rulers',
#  'are',
#  'unnecessary',
#  'and',
#  'should',
#  'be',
#  'abolished',
#  'although',
#  'there',
#  'are',
#  'differing',
#  'interpretations',
#  'of',
#  'what',
#  'this',
#  'means',
#  'anarchism',
#  'also',
#  'refers',
#  'to',
#  'related',
#  'social',
#  'movements',
#  'that',
#  'advocate',
#  'the',
#  'elimination',
#  'of',
#  'authoritarian',
#  'institutions',
#  'particularly',
#  'the',
#  'state',
#  'the',
#  'word',
#  'anarchy',
#  'as',
#  'most',
#  'anarchists',
#  'use',
#  'it',
#  'does',
#  'not',
#  'imply',
#  'chaos',
#  'nihilism',
#  'or',
#  'anomie',
#  'but',
#  'rather',
#  'a',
#  'harmonious',
#  'anti',
#  'authoritarian',
#  'society',
#  'in',
#  'place',
#  'of',
#  'what',
#  'are',
#  'regarded',
#  'as',
#  'authoritarian',
#  'political',
#  'structures',
#  'and',
#  'coercive',
#  'economic',
#  'institutions',
#  'anarchists',
#  'advocate',
#  'social',
#  'relations',
#  'based',
#  'upon',
#  'voluntary',
#  'association',
#  'of',
#  'autonomous',
#  'individuals',
#  'mutual',
#  'aid',
#  'and',
#  'self',
#  'governance',
#  'while',
#  'anarchism',
#  'is',
#  'most',
#  'easily',
#  'defined',
#  'by',
#  'what',
#  'it',
#  'is',
#  'against',
#  'anarchists',
#  'also',
#  'offer',
#  'positive',
#  'visions',
#  'of',
#  'what',
#  'they',
#  'believe',
#  'to',
#  'be',
#  'a',
#  'truly',
#  'free',
#  'society',
#  'however',
#  'ideas',
#  'about',
#  'how',
#  'an',
#  'anarchist',
#  'society',
#  'might',
#  'work',
#  'vary',
#  'considerably',
#  'especially',
#  'with',
#  'respect',
#  'to',
#  'economics',
#  'there',
#  'is',
#  'also',
#  'disagreement',
#  'about',
#  'how',
#  'a',
#  'free',
#  'society',
#  'might',
#  'be',
#  'brought',
#  'about',
#  'origins',
#  'and',
#  'predecessors',
#  'kropotkin',
#  'and',
#  'others',
#  'argue',
#  'that',
#  'before',
#  'recorded',
#  'history',
#  'human',
#  'society',
#  'was',
#  'organized',
#  'on',
#  'anarchist',
#  'principles',
#  'most',
#  'anthropologists',
#  'follow',
#  'kropotkin',
#  'and',
#  'engels',
#  'in',
#  'believing',
#  'that',
#  'hunter',
#  'gatherer',
#  'bands',
#  'were',
#  'egalitarian',
#  'and',
#  'lacked',
#  'division',
#  'of',
#  'labour',
#  'accumulated',
#  'wealth',
#  'or',
#  'decreed',
#  'law',
#  'and',
#  'had',
#  'equal',
#  'access',
#  'to',
#  'resources',
#  'william',
#  'godwin',
#  'anarchists',
#  'including',
#  'the',
#  'the',
#  'anarchy',
#  'organisation',
#  'and',
#  'rothbard',
#  'find',
#  'anarchist',
#  'attitudes',
#  'in',
#  'taoism',
#  'from',
#  'ancient',
#  'china',
#  'kropotkin',
#  'found',
#  'similar',
#  'ideas',
#  'in',
#  'stoic',
#  'zeno',
#  'of',
#  'citium',
#  'according',
#  'to',
#  'kropotkin',
#  'zeno',
#  'repudiated',
#  'the',
#  'omnipotence',
#  'of',
#  'the',
#  'state',
#  'its',
#  'intervention',
#  'and',
#  'regimentation',
#  'and',
#  'proclaimed',
#  'the',
#  'sovereignty',
#  'of',
#  'the',
#  'moral',
#  'law',
#  'of',
#  'the',
#  'individual',
#  'the',
#  'anabaptists',
#  'of',
#  'one',
#  'six',
#  'th',
#  'century',
#  'europe',
#  'are',
#  'sometimes',
#  'considered',
#  'to',
#  'be',
#  'religious',
#  'forerunners',
#  'of',
#  'modern',
#  'anarchism',
#  'bertrand',
#  'russell',
#  'in',
#  'his',
#  'history',
#  'of',
#  'western',
#  'philosophy',
#  'writes',
#  'that',
#  'the',
#  'anabaptists',
#  'repudiated',
#  'all',
#  'law',
#  'since',
#  'they',
#  'held',
#  'that',
#  'the',
#  'good',
#  'man',
#  'will',
#  'be',
#  'guided',
#  'at',
#  'every',
#  'moment',
#  'by',
#  'the',
#  'holy',
#  'spirit',
#  'from',
#  'this',
#  'premise',
#  'they',
#  'arrive',
#  'at',
#  'communism',
#  'the',
#  'diggers',
#  'or',
#  'true',
#  'levellers',
#  'were',
#  'an',
#  'early',
#  'communistic',
#  'movement',
#  'during',
#  'the',
#  'time',
#  'of',
#  'the',
#  'english',
#  'civil',
#  'war',
#  'and',
#  'are',
#  'considered',
#  'by',
#  'some',
#  'as',
#  'forerunners',
#  'of',
#  'modern',
#  'anarchism',
#  'in',
#  'the',
#  'modern',
#  'era',
#  'the',
#  'first',
#  'to',
#  'use',
#  'the',
#  'term',
#  'to',
#  'mean',
#  'something',
#  'other',
#  'than',
#  'chaos',
#  'was',
#  'louis',
#  'armand',
#  'baron',
#  'de',
#  'lahontan',
#  'in',
#  'his',
#  'nouveaux',
#  'voyages',
#  'dans',
#  'l',
#  'am',
#  'rique',
#  'septentrionale',
#  'one',
#  'seven',
#  'zero',
#  'three',
#  'where',
#  'he',
#  'described',
#  'the',
#  'indigenous',
#  'american',
#  'society',
#  'which',
#  'had',
#  'no',
#  'state',
#  'laws',
#  'prisons',
#  'priests',
#  'or',
#  'private',
#  'property',
#  'as',
#  'being',
#  'in',
#  'anarchy',
#  'russell',
#  'means',
#  'a',
#  'libertarian',
#  'and',
#  'leader',
#  'in',
#  'the',
#  'american',
#  'indian',
#  'movement',
#  'has',
#  'repeatedly',
#  'stated',
#  'that',
#  'he',
#  'is',
#  'an',
#  'anarchist',
#  'and',
#  'so',
#  'are',
#  'all',
#  'his',
#  'ancestors',
#  'in',
#  'one',
#  'seven',
#  'nine',
#  'three',
#  'in',
#  'the',
#  'thick',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'william',
#  'godwin',
#  'published',
#  'an',
#  'enquiry',
#  'concerning',
#  'political',
#  'justice',
#  'although',
#  'godwin',
#  'did',
#  'not',
#  'use',
#  'the',
#  'word',
#  'anarchism',
#  'many',
#  'later',
#  'anarchists',
#  'have',
#  'regarded',
#  'this',
#  'book',
#  'as',
#  'the',
#  'first',
#  'major',
#  'anarchist',
#  'text',
#  'and',
#  'godwin',
#  'as',
#  'the',
#  'founder',
#  'of',
#  'philosophical',
#  'anarchism',
#  'but',
#  'at',
#  'this',
#  'point',
#  'no',
#  'anarchist',
#  'movement',
#  'yet',
#  'existed',
#  'and',
#  'the',
#  'term',
#  'anarchiste',
#  'was',
#  'known',
#  'mainly',
#  'as',
#  'an',
#  'insult',
#  'hurled',
#  'by',
#  'the',
#  'bourgeois',
#  'girondins',
#  'at',
#  'more',
#  'radical',
#  'elements',
#  'in',
#  'the',
#  'french',
#  'revolution',
#  'the',
#  'first',
#  'self',
#  'labelled',
#  'anarchist',
#  'pierre',
#  'joseph',
#  'proudhon',
#  'it',
#  'is',
#  'commonly',
#  'held',
#  'that',
#  'it',
#  'wasn',
#  't',
#  'until',
#  'pierre',
#  'joseph',
#  'proudhon',
#  'published',
#  'what',
#  'is',
#  'property',
#  'in',
#  'one',
#  'eight',
#  'four',
#  'zero',
#  'that',
#  'the',
#  'term',
#  'anarchist',
#  'was',
#  'adopted',
#  'as',
#  'a',
#  'self',
#  'description',
#  'it',
#  'is',
#  'for',
#  'this',
#  'reason',
#  'that',
#  'some',
#  'claim',
#  'proudhon',
#  'as',
#  'the',
#  'founder',
#  'of',
#  'modern',
#  'anarchist',
#  'theory',
#  'in',
#  'what',
#  'is',
#  'property',
#  'proudhon',
#  'answers',
#  'with',
#  'the',
#  'famous',
#  'accusation',
#  'property',
#  'is',
#  'theft',
#  'in',
#  'this',
#  'work',
#  'he',
#  'opposed',
#  'the',
#  'institution',
#  'of',
#  'decreed',
#  'property',
#  'propri',
#  't',
#  'where',
#  'owners',
#  'have',
#  'complete',
#  'rights',
#  'to',
#  'use',
#  'and',
#  'abuse',
#  'their',
#  'property',
#  'as',
#  'they',
#  'wish',
#  'such',
#  'as',
#  'exploiting',
#  'workers',
#  'for',
#  'profit',
#  'in',
#  'its',
#  'place',
#  'proudhon',
#  'supported',
#  'what',
#  'he',
#  'called',
#  'possession',
#  'individuals',
#  'can',
#  'have',
#  'limited',
#  'rights',
#  'to',
#  'use',
#  'resources',
#  'capital',
#  'and',
#  'goods',
#  'in',
#  'accordance',
#  'with',
#  'principles',
#  'of',
#  'equality',
#  'and',
#  'justice',
#  'proudhon',
#  's',
#  'vision',
#  'of',
#  'anarchy',
#  'which',
#  'he',
#  'called',
#  'mutualism',
#  'mutuellisme',
#  'involved',
#  'an',
#  'exchange',
#  'economy',
#  'where',
#  'individuals',
#  'and',
#  'groups',
#  'could',
#  'trade',
#  'the',
#  'products',
#  'of',
#  'their',
#  'labor',
#  'using',
#  'labor',
#  'notes',
#  'which',
#  'represented',
#  'the',
#  'amount',
#  'of',
#  'working',
#  'time',
#  'involved',
#  'in',
#  'production',
#  'this',
#  'would',
#  'ensure',
#  'that',
#  'no',
#  'one',
#  'would',
#  'profit',
#  'from',
#  'the',
#  'labor',
#  'of',
#  'others',
#  'workers',
#  'could',
#  'freely',
#  'join',
#  'together',
#  'in',
#  'co',
#  'operative',
#  'workshops',
#  'an',
#  'interest',
#  'free',
#  'bank',
#  'would',
#  'be',
#  'set',
#  'up',
#  'to',
#  'provide',
#  'everyone',
#  'with',
#  'access',
#  'to',
#  'the',
#  'means',
#  'of',
#  'production',
#  'proudhon',
#  's',
#  'ideas',
#  'were',
#  'influential',
#  'within',
#  'french',
#  'working',
#  'class',
#  'movements',
#  'and',
#  'his',
#  'followers',
#  'were',
#  'active',
#  'in',
#  'the',
#  'revolution',
#  'of',
#  'one',
#  'eight',
#  'four',
#  'eight',
#  'in',
#  'france',
#  'proudhon',
#  's',
#  'philosophy',
#  'of',
#  'property',
#  'is',
#  'complex',
#  'it',
#  'was',
#  'developed',
#  'in',
#  'a',
#  'number',
#  'of',
#  'works',
#  'over',
#  'his',
#  'lifetime',
#  'and',
#  'there',
#  'are',
#  'differing',
#  'interpretations',
#  'of',
#  'some',
#  'of',
#  'his',
#  'ideas',
#  'for',
#  'more',
#  'detailed',
#  'discussion',
#  'see',
#  'here',
#  'max',
#  'stirner',
#  's',
#  'egoism',
#  'in',
#  'his',
#  'the',
#  'ego',
#  'and',
#  'its',
#  'own',
#  'stirner',
#  'argued',
#  'that',
#  'most',
#  'commonly',
#  'accepted',
#  'social',
#  'institutions',
#  'including',
#  'the',
#  'notion',
#  'of',
#  'state',
#  'property',
#  'as',
#  'a',
#  'right',
#  'natural',
#  'rights',
#  'in',
#  'general',
#  'and',
#  'the',
#  'very',
#  'notion',
#  'of',
#  'society',
#  'were',
#  'mere',
#  'illusions',
#  'or',
#  'ghosts',
#  'in',
#  'the',
#  'mind',
#  'saying',
#  'of',
#  'society',
#  'that',
#  'the',
#  'individuals',
#  'are',
#  'its',
#  'reality',
#  'he',
#  'advocated',
#  'egoism',
#  'and',
#  'a',
#  'form',
#  'of',
#  'amoralism',
#  'in',
#  'which',
#  'individuals',
#  'would',
#  'unite',
#  'in',
#  'associations',
#  'of',
#  'egoists',
#  'only',
#  'when',
#  'it',
#  'was',
#  'in',
#  'their',
#  'self',
#  'interest',
#  'to',
#  'do',
#  'so',
#  'for',
#  'him',
#  'property',
#  'simply',
#  'comes',
#  'about',
#  'through',
#  'might',
#  'whoever',
#  'knows',
#  'how',
#  'to',
#  'take',
#  'to',
#  'defend',
#  'the',
#  'thing',
#  'to',
#  'him',
#  'belongs',
#  'property',
#  'and',
#  'what',
#  'i',
#  'have',
#  'in',
#  'my',
#  'power',
#  'that',
#  'is',
#  'my',
#  'own',
#  'so',
#  'long',
#  'as',
#  'i',
#  'assert',
#  'myself',
#  'as',
#  'holder',
#  'i',
#  'am',
#  'the',
#  'proprietor',
#  'of',
#  'the',
#  'thing',
#  'stirner',
#  'never',
#  'called',
#  'himself',
#  'an',
#  'anarchist',
#  'he',
#  'accepted',
#  'only',
#  'the',
#  'label',
#  'egoist',
#  'nevertheless',
#  'his',
#  'ideas',
#  'were',
#  'influential',
#  'on',
#  'many',
#  'individualistically',
#  'inclined',
#  'anarchists',
#  'although',
#  'interpretations',
#  'of',
#  'his',
#  'thought',
#  'are',
#  'diverse',
#  ...]

# %%
vocabulary_size = 50000
words = vocabulary
n_words = vocabulary_size

"""Process raw inputs into a dataset."""
count = [['UNK', -1]]
count.extend(collections.Counter(words).most_common(n_words - 1))
dictionary = {word: index for index, (word, _) in enumerate(count)}
data = []
unk_count = 0
for word in words:
  index = dictionary.get(word, 0)
  if index == 0:  # dictionary['UNK']
    unk_count += 1
  data.append(index)
count[0][1] = unk_count
reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
data = data 
count = count
unused_dictionary = dictionary
reverse_dictionary = reversed_dictionary

# %%
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
  def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)  # pylint: disable=redefined-builtin
    if data_index + span > len(data):
      data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
      context_words = [w for w in range(span) if w != skip_window]
      words_to_use = random.sample(context_words, num_skips)
      for j, context_word in enumerate(words_to_use):
        batch[i * num_skips + j] = buffer[skip_window]
        labels[i * num_skips + j, 0] = buffer[context_word]
      if data_index == len(data):
        buffer.extend(data[0:span])
        data_index = span
      else:
        buffer.append(data[data_index])
        data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index - span) % len(data)
    return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)

# %%
batch,labels
# Out:
# (array([3081, 3081,   12,   12,    6,    6,  195,  195], dtype=int32),
#  array([[5234],
#         [  12],
#         [   6],
#         [3081],
#         [  12],
#         [ 195],
#         [   6],
#         [   2]], dtype=int32))

# %%
  for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
          reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit
# the validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():

  # Input data.
  with tf.name_scope('inputs'):
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/gpu:0'):
    # Look up embeddings for inputs.
    with tf.name_scope('embeddings'):
      embeddings = tf.Variable(
          tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
      embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    # NCE矩阵就类似于另一个辅助向量矩阵
    with tf.name_scope('weights'):
      nce_weights = tf.Variable(
          tf.truncated_normal([vocabulary_size, embedding_size],
                              stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
      nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss and why choosing NCE over tf.nn.sampled_softmax_loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  #   http://papers.nips.cc/paper/5165-learning-word-embeddings-efficiently-with-noise-contrastive-estimation.pdf
  with tf.name_scope('loss'):
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights,
            biases=nce_biases,
            labels=train_labels,
            inputs=embed,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

  # Add the loss value as a scalar to summary.
  tf.summary.scalar('loss', loss)

  # Construct the SGD optimizer using a learning rate of 1.0.
  with tf.name_scope('optimizer'):
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all
  # embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Merge all summaries.
  merged = tf.summary.merge_all()

  # Add variable initializer.
  init = tf.global_variables_initializer()

  # Create a saver.
  saver = tf.train.Saver()
# Out:
# WARNING:tensorflow:From /home/luban/miniconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/luban/miniconda3/lib/python3.6/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # Open a writer to write summaries.
  writer = tf.summary.FileWriter(log_dir, session.graph)

  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # Define metadata variable.
    run_metadata = tf.RunMetadata()

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    # Also, evaluate the merged op to get all summaries from the returned
    # "summary" variable. Feed metadata variable to session for visualizing
    # the graph in TensorBoard.
    _, summary, loss_val = session.run([optimizer, merged, loss],
                                       feed_dict=feed_dict,
                                       run_metadata=run_metadata)
    average_loss += loss_val

    # Add returned summaries to writer in each step.
    writer.add_summary(summary, step)
    # Add metadata to visualize the graph for the last run.
    if step == (num_steps - 1):
      writer.add_run_metadata(run_metadata, 'step%d' % step)

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000
      # batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word

        print(
            log_str,
            ', '.join([reverse_dictionary[nearest[k]] for k in range(top_k)]))
  final_embeddings = normalized_embeddings.eval()

  # Write corresponding labels for the embeddings.
  with open(log_dir + '/metadata.tsv', 'w') as f:
    for i in xrange(vocabulary_size):
      f.write(reverse_dictionary[i] + '\n')

  # Save the model for checkpoints.
  saver.save(session, os.path.join(log_dir, 'model.ckpt'))

  # Create a configuration for visualizing embeddings with the labels in
  # TensorBoard.
  config = projector.ProjectorConfig()
  embedding_conf = config.embeddings.add()
  embedding_conf.tensor_name = embeddings.name
  embedding_conf.metadata_path = os.path.join(log_dir, 'metadata.tsv')
  projector.visualize_embeddings(writer, config)

writer.close()
# Out:
# Initialized
# Average loss at step  0 :  290.0513916015625
# Nearest to were: epimenides, genders, murmansk, poetics, cfp, treating, stateless, maison
# Nearest to over: unveiled, aristocratic, differential, trisomy, clam, oct, exceptional, assessed
# Nearest to american: metrics, peterson, crisp, humber, him, mocked, mario, motown
# Nearest to his: identifications, idiosyncratic, assembler, huey, trevelyan, universal, masculist, elite
# Nearest to between: capitalize, guides, mcmanus, dolls, intuitive, iteration, acadian, declassified
# Nearest to nine: healer, hunyadi, catwoman, cpr, sect, plutonium, dymaxion, fleming
# Nearest to new: strained, dots, muhammed, endocrine, boleslav, stephan, braintree, hird
# Nearest to four: feminist, np, stocked, buber, traditional, doctoral, nielsen, solitaire
# Nearest to one: tertiary, confines, mayo, acm, mcgwire, latinate, sunken, pepper
# Nearest to its: iii, rafik, kathmandu, deferred, verily, tofu, hollingworth, inspired
# Nearest to called: organizers, peuple, sampson, thr, tasmanian, marija, dairy, fields
# Nearest to in: requires, susa, wanda, tardive, medici, inexpensively, broke, complements
# Nearest to was: flirt, unfortunate, nest, springs, toss, woodsman, cusp, consumers
# Nearest to so: frankly, pinky, kongo, closer, gibbons, dragoon, beethoven, criterion
# Nearest to s: aborted, threaded, ruin, optical, imbalance, smelting, visual, tattoo
# Nearest to see: fined, entire, inquisitor, iww, welcomes, musicbrainz, expanses, dazzling
# Average loss at step  2000 :  113.83323375034333
# Average loss at step  4000 :  53.63613258862495
# Average loss at step  6000 :  33.584041556835174
# Average loss at step  8000 :  23.350853157281875
# Average loss at step  10000 :  17.61061564385891
# Nearest to were: was, dasyprocta, gustave, are, solf, operatorname, and, temporary
# Nearest to over: five, dasyprocta, circ, differential, agouti, reserved, unveiled, alabama
# Nearest to american: vocals, and, mario, connections, him, sal, acronym, agouti
# Nearest to his: the, a, peptide, universal, able, and, alexandria, abort
# Nearest to between: masoretic, ribs, forms, himself, worshipped, intuitive, baby, guides
# Nearest to nine: circ, dasyprocta, eight, zero, agouti, operatorname, seven, six
# Nearest to new: original, alphorn, peptidoglycan, thousands, strained, dots, located, japan
# Nearest to four: dasyprocta, circ, agouti, zero, three, two, nine, eight
# Nearest to one: circ, agouti, dasyprocta, and, operatorname, two, nine, stuff
# Nearest to its: the, yin, beads, iii, circ, western, axiom, inspired
# Nearest to called: dasyprocta, august, fields, wind, seven, agouti, country, density
# Nearest to in: of, and, for, on, circ, nine, agouti, from
# Nearest to was: is, circ, and, jon, were, nine, stuff, bombay
# Nearest to so: circ, closer, abort, hitchcock, frankly, profitable, membership, agouti
# Nearest to s: and, the, of, circ, four, refers, axioms, egyptian
# Nearest to see: entire, hbox, instruments, franks, agouti, print, archie, combination
# Average loss at step  12000 :  13.54813468182087
# Average loss at step  14000 :  11.497108426094055
# Average loss at step  16000 :  9.602988170862197
# Average loss at step  18000 :  8.695578143239022
# Average loss at step  20000 :  7.934743778705597
# Nearest to were: are, was, had, is, dasyprocta, and, but, poorly
# Nearest to over: five, unveiled, circ, differential, dasyprocta, reserved, sweet, as
# Nearest to american: vocals, crisp, sal, connections, english, mario, and, hamza
# Nearest to his: the, its, their, universal, peptide, elgin, abet, a
# Nearest to between: masoretic, in, worshipped, dolls, ribs, baby, other, intuitive
# Nearest to nine: eight, six, five, seven, zero, three, dasyprocta, circ
# Nearest to new: original, dots, endocrine, alphorn, strained, apologia, peptidoglycan, thousands
# Nearest to four: nine, eight, six, three, two, seven, dasyprocta, circ
# Nearest to one: two, circ, agouti, dasyprocta, operatorname, six, eight, three
# Nearest to its: the, their, his, beads, yin, triangles, hometown, this
# Nearest to called: fields, dasyprocta, august, seven, wind, density, downed, pacific
# Nearest to in: and, at, of, on, nine, from, for, circ
# Nearest to was: is, were, had, by, circ, are, meridians, has
# Nearest to so: circ, pinky, closer, frankly, abort, bachchan, truetype, profitable
# Nearest to s: and, circ, five, zero, of, four, two, antwerp
# Nearest to see: entire, hbox, instruments, franks, print, welcomes, cardinality, rose
# Average loss at step  22000 :  7.410149010896682
# Average loss at step  24000 :  6.725026188969612
# Average loss at step  26000 :  6.676856071472168
# Average loss at step  28000 :  6.2763167155981066
# Average loss at step  30000 :  6.220449869275093
# Nearest to were: are, was, had, is, have, be, but, dasyprocta
# Nearest to over: as, unveiled, circ, reserved, five, dasyprocta, agouti, rated
# Nearest to american: vocals, and, english, sal, crisp, mario, agouti, connections
# Nearest to his: their, the, its, vma, s, a, universal, elgin
# Nearest to between: in, masoretic, worshipped, ribs, against, declassified, dolls, baby
# Nearest to nine: eight, seven, six, five, three, four, zero, circ
# Nearest to new: original, endocrine, dots, vma, alphorn, strained, apologia, aspirin
# Nearest to four: six, three, eight, seven, five, two, nine, zero
# Nearest to one: two, four, seven, three, six, eight, circ, five
# Nearest to its: the, their, his, beads, this, hometown, yin, circ
# Nearest to called: amphibian, also, fields, wind, density, downed, aba, gerald
# Nearest to in: and, at, from, on, nine, with, for, of
# Nearest to was: is, were, had, by, appomattox, has, became, are
# Nearest to so: circ, frankly, pinky, profitable, bachchan, abort, closer, truetype
# Nearest to s: and, zero, circ, the, two, appomattox, five, apatosaurus
# Nearest to see: entire, hbox, instruments, cardinality, imbalance, trinomial, franks, iww
# Average loss at step  32000 :  6.012097638487816
# Average loss at step  34000 :  5.379690288066864
# Average loss at step  36000 :  5.675213671445847
# Average loss at step  38000 :  5.478682274103165
# Average loss at step  40000 :  5.422163818120956
# Nearest to were: are, was, had, is, have, be, poorly, dasyprocta
# Nearest to over: four, unveiled, as, fielder, reserved, dasyprocta, circ, sweet
# Nearest to american: english, mario, sal, vocals, crisp, connections, lancastrian, hamza
# Nearest to his: their, its, the, vma, her, s, dasyprocta, elgin
# Nearest to between: masoretic, worshipped, ribs, with, in, against, from, dolls
# Nearest to nine: eight, six, seven, five, zero, four, three, antwerp
# Nearest to new: original, dots, endocrine, vma, lemmy, alphorn, strained, aspirin
# Nearest to four: six, five, three, eight, seven, two, nine, zero
# Nearest to one: two, four, five, seven, three, six, eight, agouti
# Nearest to its: the, their, his, beads, hometown, circ, this, akh
# Nearest to called: organizers, amphibian, gerald, also, downed, dasyprocta, aba, fields
# Nearest to in: at, on, from, and, during, nine, of, circ
# Nearest to was: is, were, had, has, by, appomattox, became, circ
# Nearest to so: ayling, circ, profitable, pinky, bachchan, frankly, hitchcock, truetype
# Nearest to s: and, circ, his, appomattox, operatorname, ize, antwerp, msg
# Nearest to see: entire, instruments, cardinality, welcomes, hbox, imbalance, trinomial, eno
# Average loss at step  42000 :  5.378047428965568
# Average loss at step  44000 :  5.208222738981247
# Average loss at step  46000 :  5.226727627038955
# Average loss at step  48000 :  5.191692828893662
# Average loss at step  50000 :  5.201350687623024
# Nearest to were: are, was, have, had, is, be, poorly, dasyprocta
# Nearest to over: kapoor, unveiled, fielder, ursus, reserved, four, circ, dasyprocta
# Nearest to american: english, sal, mario, crisp, vocals, connections, lancastrian, agouti
# Nearest to his: their, its, the, her, vma, s, abet, harrier
# Nearest to between: in, masoretic, with, worshipped, against, ribs, from, declassified
# Nearest to nine: eight, six, seven, four, five, zero, three, ursus
# Nearest to new: original, lemmy, dots, vma, endocrine, strained, aspirin, alphorn
# Nearest to four: eight, six, five, three, nine, two, seven, zero
# Nearest to one: two, three, six, eight, five, seven, four, kapoor
# Nearest to its: their, the, his, hometown, beads, circ, ursus, kapoor
# Nearest to called: kapoor, organizers, amphibian, dasyprocta, gerald, aba, msg, prc
# Nearest to in: at, on, and, from, during, ursus, of, circ
# Nearest to was: is, has, had, were, appomattox, by, became, kapoor
# Nearest to so: ayling, profitable, circ, truetype, pinky, hitchcock, abort, then
# Nearest to s: zero, and, his, circ, msg, was, antwerp, ursus
# Nearest to see: wct, entire, and, cardinality, instruments, hbox, kapoor, welcomes
# Average loss at step  52000 :  5.118528266787529
# Average loss at step  54000 :  5.129140429139137
# Average loss at step  56000 :  5.0594345652461055
# Average loss at step  58000 :  4.971845050096512
# Average loss at step  60000 :  4.768472163081169
# Nearest to were: are, was, had, have, is, be, await, but
# Nearest to over: kapoor, four, five, ursus, unveiled, reserved, microcebus, fielder
# Nearest to american: english, sal, mario, vocals, crisp, connections, agouti, unmixed
# Nearest to his: their, its, her, the, vma, abet, ursus, s
# Nearest to between: with, in, masoretic, against, from, worshipped, ribs, declassified
# Nearest to nine: eight, seven, six, five, zero, four, microcebus, kapoor
# Nearest to new: lemmy, original, dots, vma, endocrine, strained, aspirin, alphorn
# Nearest to four: five, six, three, eight, two, seven, circ, dasyprocta
# Nearest to one: two, six, seven, four, three, five, eight, kapoor
# Nearest to its: their, the, his, michelob, ursus, hometown, circ, beads
# Nearest to called: UNK, microcebus, kapoor, amphibian, gerald, dasyprocta, organizers, prc
# Nearest to in: during, at, microcebus, on, from, ursus, since, and
# Nearest to was: is, has, had, were, by, became, appomattox, when
# Nearest to so: ayling, profitable, circ, hitchcock, then, truetype, pinky, bachchan
# Nearest to s: zero, circ, and, msg, antwerp, operatorname, four, pulau
# Nearest to see: wct, but, entire, cardinality, instruments, hbox, welcomes, kapoor
# Average loss at step  62000 :  4.917763850808144
# Average loss at step  64000 :  4.963170902967453
# Average loss at step  66000 :  4.914801275610924
# Average loss at step  68000 :  4.783443078517914
# Average loss at step  70000 :  4.816712886333465
# Nearest to were: are, was, have, had, be, await, is, electroconvulsive
# Nearest to over: kapoor, four, unveiled, fielder, ursus, reserved, five, microcebus
# Nearest to american: english, sal, mario, vocals, crisp, connections, unmixed, ptolemy
# Nearest to his: their, its, her, the, vma, s, ursus, abet
# Nearest to between: with, masoretic, against, from, in, ribs, worshipped, declassified
# Nearest to nine: eight, seven, six, five, zero, thaler, four, kapoor
# Nearest to new: lemmy, original, dots, vma, endocrine, strained, aspirin, one
# Nearest to four: five, six, three, seven, eight, two, thaler, one
# Nearest to one: six, four, two, seven, five, three, kapoor, dinar
# Nearest to its: their, the, his, any, michelob, ursus, circ, thaler
# Nearest to called: microcebus, gerald, kapoor, amphibian, prc, dasyprocta, organizers, used
# Nearest to in: microcebus, during, ursus, at, nine, since, circ, and
# Nearest to was: is, has, had, were, appomattox, became, by, circ
# Nearest to so: ayling, profitable, circ, then, hitchcock, truetype, bachchan, kapoor
# Nearest to s: zero, his, and, circ, msg, antwerp, operatorname, pulau
# Nearest to see: but, wct, thaler, appomattox, kapoor, and, instruments, welcomes
# Average loss at step  72000 :  4.832925908207893
# Average loss at step  74000 :  4.8674311826229095
# Average loss at step  76000 :  4.813297612905503
# Average loss at step  78000 :  4.831177832603455
# Average loss at step  80000 :  4.813945890545845
# Nearest to were: are, was, have, had, be, is, including, by
# Nearest to over: kapoor, trisomy, four, ursus, unveiled, fielder, reserved, warden
# Nearest to american: english, sal, mario, iit, crisp, vocals, agouti, connections
# Nearest to his: their, her, its, the, vma, s, abet, ursus
# Nearest to between: with, in, masoretic, from, against, ribs, worshipped, declassified
# Nearest to nine: eight, seven, six, five, four, zero, thaler, kapoor
# Nearest to new: lemmy, vma, original, dots, strained, endocrine, iit, aspirin
# Nearest to four: six, five, three, seven, eight, two, nine, one
# Nearest to one: six, two, seven, four, three, five, eight, kapoor
# Nearest to its: their, his, the, michelob, circ, her, ursus, thaler
# Nearest to called: microcebus, gerald, UNK, iit, kapoor, amphibian, dasyprocta, prc
# Nearest to in: during, at, from, microcebus, on, and, since, until
# Nearest to was: is, has, were, had, became, appomattox, by, be
# Nearest to so: ayling, profitable, then, circ, frankly, hitchcock, truetype, abort
# Nearest to s: circ, and, zero, his, antwerp, operatorname, msg, pulau
# Nearest to see: but, wct, thaler, appomattox, cardinality, wysiwyg, welcomes, instruments
# Average loss at step  82000 :  4.780132972717285
# Average loss at step  84000 :  4.771303021073342
# Average loss at step  86000 :  4.707752115607262
# Average loss at step  88000 :  4.749396086573601
# Average loss at step  90000 :  4.718146110296249
# Nearest to were: are, was, have, had, be, including, is, while
# Nearest to over: kapoor, trisomy, unveiled, fielder, overhaul, through, warden, ursus
# Nearest to american: english, sal, mario, crisp, british, unmixed, connections, vocals
# Nearest to his: their, her, its, the, s, vma, spanned, abet
# Nearest to between: with, masoretic, from, in, against, ribs, impeached, worshipped
# Nearest to nine: eight, seven, six, five, four, zero, thaler, ursus
# Nearest to new: lemmy, vma, original, dots, endocrine, strained, one, iit
# Nearest to four: five, six, seven, eight, three, two, one, nine
# Nearest to one: two, four, six, seven, five, eight, three, kapoor
# Nearest to its: their, his, the, her, michelob, circ, any, ursus
# Nearest to called: microcebus, gerald, kapoor, used, amphibian, iit, dasyprocta, prc
# Nearest to in: during, at, microcebus, ursus, on, since, until, within
# Nearest to was: is, had, has, were, became, appomattox, by, been
# Nearest to so: ayling, then, profitable, circ, abort, truetype, frankly, pinky
# Nearest to s: his, msg, circ, and, pulau, antwerp, appomattox, zero
# Nearest to see: but, appomattox, wct, thaler, circ, kapoor, cardinality, globemaster
# Average loss at step  92000 :  4.639704519152641
# Average loss at step  94000 :  4.679459683299065
# Average loss at step  96000 :  4.69049745452404
# Average loss at step  98000 :  4.660134808897972
# Average loss at step  100000 :  4.650501203298568
# Nearest to were: are, was, have, had, be, is, including, while
# Nearest to over: kapoor, four, trisomy, through, unveiled, rigging, about, ursus
# Nearest to american: english, sal, british, mario, agouti, iit, crisp, dasyprocta
# Nearest to his: their, her, its, the, s, vma, spanned, abet
# Nearest to between: with, masoretic, against, in, from, ribs, metroid, declassified
# Nearest to nine: eight, seven, six, five, four, zero, thaler, kapoor
# Nearest to new: lemmy, original, vma, dots, endocrine, strained, iit, small
# Nearest to four: five, six, seven, eight, three, two, thaler, nine
# Nearest to one: seven, two, four, six, eight, five, three, agouti
# Nearest to its: their, his, the, her, michelob, circ, ursus, any
# Nearest to called: microcebus, gerald, used, amphibian, iit, kapoor, prc, msg
# Nearest to in: during, at, within, microcebus, from, on, ursus, beeb
# Nearest to was: is, had, has, were, became, appomattox, been, when
# Nearest to so: ayling, then, profitable, circ, when, abort, truetype, frankly
# Nearest to s: his, circ, pulau, acacia, and, msg, five, antwerp
# Nearest to see: but, appomattox, wct, thaler, welcomes, circ, instruments, cardinality

# %%
# Step 6: Visualize the embeddings.

  # pylint: disable=missing-docstring
  # Function to draw visualization of distance between embeddings.
  def plot_with_labels(low_dim_embs, labels, filename):
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
      x, y = low_dim_embs[i, :]
      plt.scatter(x, y)
      plt.annotate(
          label,
          xy=(x, y),
          xytext=(5, 2),
          textcoords='offset points',
          ha='right',
          va='bottom')

    plt.savefig(filename)
    plt.show()

  try:
    # pylint: disable=g-import-not-at-top
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt

    tsne = TSNE(
        perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(),
                                                        'tsne.png'))

  except ImportError as ex:
    print('Please install sklearn, matplotlib, and scipy to show embeddings.')
    print(ex)
